# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %% [markdown]
# # Conhecendo os dados e explorando

# %% [markdown]
# ## Analisaremos o TMDB 5000

# %%
tmdb = pd.read_csv('tmdb_5000/tmdb_5000_movies.csv')

tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb['vote_average'], kde=True)
ax.set(xlabel='Nota média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no TMDB 5000')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb['vote_average'], norm_hist=False, kde=False)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Média de votos em filmes no TMDB 5000')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.boxplot(x=tmdb['vote_average'])
ax.set(xlabel='Nota média do filme')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000')
plt.show()

# %% [markdown]
# **Uma informação bastante importante pode ser extraída dessas visualizações: uma quantidade razoável de filmes possuem média 0 e 10. Isso parece estranho, pois qualquer nota diferente de 0 ou 10, respectivamente, seria suficiente para mudar essas médias. Vamos verificar o que está acontecendo com nossos dados.**

# %%
tmdb.query('vote_average == 0.0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %% [markdown]
# **O importante, aqui, é a coluna "vote_count. Perceba que a maior parte dos filmes cuja média é 0 também possuem um número de votos igual a 0. Porém, se não existiram votos, o filme não deveria constar na plotagem dos nossos dados, já que não existe informação sobre a nota dele - diferente do que nos é apresentado agora, com a nota 0 identificando-os como filmes ruins.**
#
# **Portanto, teremos que remover esses registros do nosso dataframe. Manteremos somente os registros com 10 ou mais notas. Atribuiremos esse novo conjunto a uma variável diferente e usaremos describe() para exibirmos algumas de suas características:**

# %%
tmdb_10_votos = tmdb.query('vote_count >= 10')

tmdb_10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
tmdb.query('vote_average == 10.0')
# Out:
#       budget                                             genres homepage  \
# 3519       0                     [{"id": 35, "name": "Comedy"}]      NaN
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...      NaN
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...      NaN
# 4662       0                     [{"id": 35, "name": "Comedy"}]      NaN
#
#           id                                           keywords  \
# 3519   89861  [{"id": 131, "name": "italy"}, {"id": 8250, "n...
# 4045   78373  [{"id": 1415, "name": "small town"}, {"id": 15...
# 4247  361505                                                 []
# 4662   40963        [{"id": 10183, "name": "independent film"}]
#
#      original_language         original_title  \
# 3519                en       Stiff Upper Lips
# 4045                en  Dancer, Texas Pop. 81
# 4247                en  Me You and Five Bucks
# 4662                en         Little Big Top
#
# ...

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb_10_votos['vote_average'], norm_hist=False, kde=False)
ax.set(xlabel='Nota média', ylabel='Frequência')
ax.set_title('Média de votos em filmes no TMDB 5000 dentre os filmes com 10 ou mais votos')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb_10_votos['vote_average'], kde=True)
ax.set(xlabel='Nota média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no TMDB 5000 dentre os filmes com 10 ou mais votos')
plt.show()

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(
    tmdb_10_votos['vote_average'], 
    kde=True, 
    hist_kws={'cumulative' : True},
    kde_kws={'cumulative' : True}
)
ax.set(xlabel='Nota média', ylabel='% acumulada de filmes')
ax.set_title('Média de votos em filmes no TMDB 5000 com 10 ou mais votos')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.boxplot(x=tmdb_10_votos['vote_average'])
ax.set(xlabel='Nota média do filme')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000 dentre os filmes com 10 ou mais votos')
plt.show()

# %% [markdown]
# # Analisaremos também o movielens

# %%
notas_movielens = pd.read_csv('ml-latest-small/ratings.csv')

notas_movielens.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_filme = notas_movielens.groupby('movieId').mean()['rating']

nota_media_filme
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(nota_media_filme.values, kde=True)
ax.set(xlabel='Nota média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no Movielens 100k')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
qtd_votos_por_filme = notas_movielens.groupby('movieId').count()
filmes_10_votos_movielens = qtd_votos_por_filme.query('rating >= 10').index
filmes_10_votos_movielens.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593])

# %%
nota_media_filme
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
nota_media_filme_10_votos = nota_media_filme.loc[filmes_10_votos_movielens.values]
nota_media_filme_10_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(nota_media_filme_10_votos.values, kde=True)
ax.set(xlabel='Nota média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no Movielens 100k com 10 ou mais votos')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.boxplot(x=nota_media_filme_10_votos.values)
ax.set(xlabel='Nota média do filme')
ax.set_title('Distribuição de nota média dos filmes do MovieLens 100k dentre os filmes com 10 ou mais votos')
plt.show()

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(
    nota_media_filme_10_votos.values, 
    kde=True, 
    hist_kws={'cumulative' : True},
    kde_kws={'cumulative' : True}
)
ax.set(xlabel='Nota média', ylabel='% acumulada de filmes')
ax.set_title('Média de votos em filmes no Movielens 100k com 10 ou mais votos')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Explorando as distribuições das amostras

# %% [markdown]
# ## Analisando a distribuição dos dados capturados de outros campos do TMDB

# %%
tmdb_10_votos['vote_count']
# Out:
# 0       11800
# 1        4500
# 2        4466
# 3        9106
# 4        2124
#         ...
# 4790       17
# 4792       63
# 4796      658
# 4798      238
# 4802       16
# Name: vote_count, Length: 4392, dtype: int64

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb_10_votos['vote_count'], kde=True)
ax.set(xlabel='Número de votos', ylabel='Densidade')
ax.set_title('Número de votos em filmes no TMDB 5000 com 10 ou mais votos')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb.query('budget > 0')['budget'], kde=True)
ax.set(xlabel='Budget (gastos)', ylabel='Densidade')
ax.set_title('Gastos em filmes no TMDB 5000')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb['popularity'], kde=True)
ax.set(xlabel='Popularidade', ylabel='Densidade')
ax.set_title('Popularidade em filmes no TMDB 5000')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
tmdb['runtime'].isnull().sum()
# Out:
# 2

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(tmdb.query('runtime > 0')['runtime'].dropna(), kde=True)
ax.set(xlabel='Tempo de duração', ylabel='Densidade')
ax.set_title('Tempo de duração em filmes no TMDB 5000')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(
    tmdb.query('runtime > 0')['runtime'].dropna(), 
    kde=True,
    hist_kws={'cumulative' : True},
    kde_kws={'cumulative' : True}
)
ax.set(xlabel='Tempo de duração', ylabel='% de filmes')
ax.set_title('Tempo de duração em filmes no TMDB 5000')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
tmdb.query('runtime > 0')['runtime'].dropna().quantile(q=0.8)
# Out:
# 121.0

# %% [markdown]
# # Testes de uma amostra

# %% [markdown]
# ## Movielens: média dos filmes com pelo menos 10 votos

# %%
print('Média dos filmes com pelo menos 10 votos:', nota_media_filme_10_votos.mean())
# Out:
# Média dos filmes com pelo menos 10 votos: 3.4320503405352603

# %%
nota_media_filme_10_votos.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 5    3.071429
# 6    3.946078
# Name: rating, dtype: float64

# %%
plt.figure(dpi=300)
medias = []

for i in range(1, len(nota_media_filme_10_votos)):
    medias.append(nota_media_filme_10_votos[0:i].mean())

plt.plot(medias)
plt.show()

# %%
plt.figure(dpi=300)
np.random.seed(75243)
temp = nota_media_filme_10_votos.sample(frac=1)

medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)
plt.show()

# %%
from statsmodels.stats.weightstats import zconfint
from statsmodels.stats.weightstats import DescrStatsW

# %%
zconfint(nota_media_filme_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
descr_filmes_com_votos = DescrStatsW(nota_media_filme_10_votos)
descr_filmes_com_votos.tconfint_mean()
# Out:
# (3.41123483922938, 3.4528658418411386)

# %% [markdown]
# # Outros testes

# %% [markdown]
# ## Vamos ver o filme 1...

# %%
filmes = pd.read_csv('ml-latest-small/movies.csv')

filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas1 = notas_movielens.query('movieId == 1')

notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
f = plt.figure(dpi=300)
ax = sns.distplot(notas1['rating'], kde=True)
ax.set(xlabel='Nota', ylabel='Densidade')
ax.set_title('Distribuição das notas para o Toy Story')
plt.show()
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f = plt.figure(dpi=300)
ax = sns.boxplot(notas1['rating'])
ax.set(xlabel='Nota')
ax.set_title('Distribuição das notas para o Toy Story')
# Out:
# /home/gabriel/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribuição das notas para o Toy Story')

# %%
notas1['rating'].mean()
# Out:
# 3.9209302325581397

# %%
notas1['rating'].count()
# Out:
# 215

# %%
zconfint(notas1['rating'])
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

# %%
_, p_value = ztest(notas1['rating'], value=nota_media_filme_10_votos.mean())

# %%
p_value <= 0.05
# Out:
# True

# %%
plt.figure(dpi=300)
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)
plt.show()

# %%
def measure_test(i):
    mean = temp[0:i].mean()
    _, p = ztest(temp[0:i], value=nota_media_filme_10_votos.mean())
    return (i, mean, p)

plt.figure(dpi=300)
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

valores = np.array([measure_test(i) for i in range(2, len(temp))])

plt.plot(valores[:, 0], valores[:, 1])
plt.hlines(y=0.05, xmin=2, xmax=len(temp), colors='red', linestyles='dashed')
plt.plot(valores[:, 0], valores[:, 2], 'green')
plt.show()

# %% [markdown]
# ## Comparação de dois conjuntos de amostras

# %%
print(ztest(notas1.rating, notas_movielens.rating))
zconfint(notas1.rating, notas_movielens.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)
# (0.2799245129192442, 0.5588219849631111)

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(notas_movielens.rating, notas1.rating)
# Out:
# Ttest_indResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09)

# %%
descr_todas_notas = DescrStatsW(notas_movielens.rating)
descr_toy_story = DescrStatsW(notas1.rating)
comparacao = descr_todas_notas.get_compare(descr_toy_story)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
f = plt.figure(dpi=300)
plt.boxplot([notas_movielens.rating, notas1.rating], labels=['Todas as notas', 'Toy Story'])
plt.title('Distribuição das notas de acordo com filmes')
plt.show()

# %%
f = plt.figure(dpi=300)
plt.boxplot([notas_movielens.rating, notas1[3:12].rating], labels=['Todas as notas', 'Toy Story (do 3 ao 12)'])
plt.title('Distribuição das notas de acordo com filmes')
plt.show()

# %%
descr_todas_notas = DescrStatsW(notas_movielens.rating)
descr_toy_story = DescrStatsW(notas1[3:12].rating)
comparacao = descr_todas_notas.get_compare(descr_toy_story)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # Não paramétricos

# %% [markdown]
# ## Comparar a média de dois filmes

# %%
filmes.query('movieId in [1, 593, 72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas593 = notas_movielens.query('movieId == 593')
notas72226 = notas_movielens.query('movieId == 72226')

f = plt.figure(dpi=300)

plt.boxplot([
        notas1.rating, 
        notas593.rating,
        notas72226.rating
    ], 
    labels=[
        'Toy Story (1995)', 
        'The Silence of the Lambs (1991)',
        'Fantastic Mr. Fox (2009)'
    ]
)

plt.xticks(fontsize=8)
plt.title('Distribuição das notas de acordo com os filmes')
plt.show()

# %%
f = plt.figure(dpi=300)
sns.boxplot(
    x='movieId',
    y='rating',
    data=notas_movielens.query('movieId in (1, 593, 72226)')
)

plt.show()

# %%
descr_1 = DescrStatsW(notas1.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_1.get_compare(descr_593)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
descr_72226 = DescrStatsW(notas72226.rating)
comparacao = descr_72226.get_compare(descr_593)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_1.get_compare(descr_72226)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
notas_movielens.query('movieId in (1, 593, 72226)').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
from scipy.stats import normaltest

# %%
_, p_value = normaltest(notas1.rating)

print('p valor =', p_value)
# Out:
# p valor = 0.00011053430732728716

# %%
from scipy.stats import ranksums

# %%
_, p_value = ranksums(notas1['rating'], notas593['rating'])

print('p valor =', p_value)
print('p valor <= significância:', p_value <= 0.05)
# Out:
# p valor = 0.0003267718756440693
# p valor <= significância: True
