# %% [markdown]
# # Criando os nomes:

# %%
import pandas as pd

# %%
nomes_f = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-f.json')
nomes_m = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-m.json')

# %%
nomes_f
# Out:
#           nome  regiao      freq  rank sexo
# 0        MARIA       0  11694738     1    F
# 1          ANA       0   3079729     2    F
# 2    FRANCISCA       0    721637     3    F
# 3      ANTONIA       0    588783     4    F
# 4      ADRIANA       0    565621     5    F
# ..         ...     ...       ...   ...  ...
# 195     ROSANE       0     82203   196    F
# 196    IVONETE       0     81878   197    F
# 197    LUCIANE       0     81230   198    F
# 198    ISADORA       0     81100   199    F
# 199      NILZA       0     80128   200    F
#
# [200 rows x 5 columns]

# %%
nomes_m
# Out:
#           nome  regiao     freq  rank sexo
# 0         JOSE       0  5732508     1    M
# 1         JOAO       0  2971935     2    M
# 2      ANTONIO       0  2567494     3    M
# 3    FRANCISCO       0  1765197     4    M
# 4       CARLOS       0  1483121     5    M
# ..         ...     ...      ...   ...  ...
# 195     WALTER       0    67207   196    M
# 196    ARLINDO       0    66669   197    M
# 197    MICHAEL       0    65736   198    M
# 198     ALVARO       0    65444   199    M
# 199    GEOVANE       0    65435   200    M
#
# [200 rows x 5 columns]

# %%
nomes_f.sample(5)
# Out:
#          nome  regiao    freq  rank sexo
# 29     RENATA       0  345195    30    F
# 27      LUANA       0  354625    28    F
# 57     DAIANE       0  243820    58    F
# 128     JOICE       0  127087   129    F
# 151  SEVERINA       0  105892   152    F

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()
nomes
# Out:
#           nome
# 0        MARIA
# 1          ANA
# 2    FRANCISCA
# 3      ANTONIA
# 4      ADRIANA
# ..         ...
# 195     WALTER
# 196    ARLINDO
# 197    MICHAEL
# 198     ALVARO
# 199    GEOVANE
#
# [400 rows x 1 columns]

# %%
nomes.sample(5)
# Out:
#          nome
# 52     SAMUEL
# 158    INGRID
# 193  LUCILENE
# 188  VALDECIR
# 166     KELLY

# %% [markdown]
# # Incluindo ID dos alunos:

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = nomes.shape[0]
total_alunos
# Out:
# 400

# %%
nomes['id_aluno'] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(5)
# Out:
#           nome  id_aluno
# 188    POLIANA       369
# 57      DAIANE       303
# 3    FRANCISCO       382
# 182    CHARLES        33
# 30    ANDERSON       111

# %%
dominios = ['@dominiodoemail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)
nomes
# Out:
#           nome  id_aluno                 dominio
# 0        MARIA       235  @dominiodoemail.com.br
# 1          ANA        43     @servicodoemail.com
# 2    FRANCISCA       304     @servicodoemail.com
# 3      ANTONIA       156  @dominiodoemail.com.br
# 4      ADRIANA       343     @servicodoemail.com
# ..         ...       ...                     ...
# 195     WALTER       231  @dominiodoemail.com.br
# 196    ARLINDO        99     @servicodoemail.com
# 197    MICHAEL       323  @dominiodoemail.com.br
# 198     ALVARO       383  @dominiodoemail.com.br
# 199    GEOVANE       366     @servicodoemail.com
#
# [400 rows x 3 columns]

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()
nomes
# Out:
#           nome  id_aluno                 dominio  \
# 0        MARIA       235  @dominiodoemail.com.br
# 1          ANA        43     @servicodoemail.com
# 2    FRANCISCA       304     @servicodoemail.com
# 3      ANTONIA       156  @dominiodoemail.com.br
# 4      ADRIANA       343     @servicodoemail.com
# ..         ...       ...                     ...
# 195     WALTER       231  @dominiodoemail.com.br
# 196    ARLINDO        99     @servicodoemail.com
# 197    MICHAEL       323  @dominiodoemail.com.br
# 198     ALVARO       383  @dominiodoemail.com.br
# 199    GEOVANE       366     @servicodoemail.com
#
#                              email
# 0      maria@dominiodoemail.com.br
# 1           ana@servicodoemail.com
# 2     francisca@servicodoemail.com
# 3    antonia@dominiodoemail.com.br
# 4       adriana@servicodoemail.com
# ..                             ...
# 195   walter@dominiodoemail.com.br
# 196     arlindo@servicodoemail.com
# 197  michael@dominiodoemail.com.br
# ...

# %% [markdown]
# # Criando a tabela cursos:

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
cursos = cursos[0]
cursos
# Out:
#                           Nome do curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %% [markdown]
# # Alterando o index de cursos:

# %%
cursos.rename(columns={'Nome do curso' : 'nome_do_curso'}, inplace=True)
cursos
# Out:
#                           nome_do_curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos['id'] = cursos.index + 1

# %%
cursos
# Out:
#                           nome_do_curso  id
# 0                 Lógica de programação   1
# 1                         Java para Web   2
# 2                           C# para Web   3
# 3                         Ruby on Rails   4
# 4                      Cursos de Python   5
# 5                         PHP com MySql   6
# 6                         .NET para web   7
# 7            Novas integrações com Java   8
# 8                          TDD com Java   9
# 9                   Código limpo com C#  10
# 10  Preparatório para certificação Java  11
# 11                      Hardware básico  12
# 12                Persistência com .NET  13
# 13                  Desenvolvendo jogos  14
# 14                     Análise de dados  15
# 15                   Estatística básica  16
# 16                  Internet das coisas  17
# 17                Programação funcional  18
# 18                Boas práticas em Java  19
# 19          Orientação objetos com Java  20

# %%
cursos.set_index('id', inplace=True)
cursos
# Out:
#                           nome_do_curso
# id
# 1                 Lógica de programação
# 2                         Java para Web
# 3                           C# para Web
# 4                         Ruby on Rails
# 5                      Cursos de Python
# 6                         PHP com MySql
# 7                         .NET para web
# 8            Novas integrações com Java
# 9                          TDD com Java
# 10                  Código limpo com C#
# 11  Preparatório para certificação Java
# 12                      Hardware básico
# 13                Persistência com .NET
# 14                  Desenvolvendo jogos
# 15                     Análise de dados
# 16                   Estatística básica
# 17                  Internet das coisas
# 18                Programação funcional
# 19                Boas práticas em Java
# 20          Orientação objetos com Java

# %% [markdown]
# # Matriculando os alunos nos cursos:

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)
nomes
# Out:
#           nome  id_aluno                 dominio  \
# 0        MARIA       235  @dominiodoemail.com.br
# 1          ANA        43     @servicodoemail.com
# 2    FRANCISCA       304     @servicodoemail.com
# 3      ANTONIA       156  @dominiodoemail.com.br
# 4      ADRIANA       343     @servicodoemail.com
# ..         ...       ...                     ...
# 195     WALTER       231  @dominiodoemail.com.br
# 196    ARLINDO        99     @servicodoemail.com
# 197    MICHAEL       323  @dominiodoemail.com.br
# 198     ALVARO       383  @dominiodoemail.com.br
# 199    GEOVANE       366     @servicodoemail.com
#
#                              email  matriculas
# 0      maria@dominiodoemail.com.br           1
# 1           ana@servicodoemail.com           5
# 2     francisca@servicodoemail.com           1
# 3    antonia@dominiodoemail.com.br           5
# 4       adriana@servicodoemail.com           1
# ..                             ...         ...
# ...

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.120000
# std        1.498738
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       10.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# %%
sns.histplot(nomes.matriculas, color="red", kde=True, stat="density", linewidth=0)
plt.show()

# %%
nomes.matriculas.value_counts()
# Out:
# 1     186
# 2      98
# 3      55
# 4      36
# 5      13
# 7       6
# 8       2
# 9       2
# 6       1
# 10      1
# Name: matriculas, dtype: int64

# %% [markdown]
# # Selecionando cursos:

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
    id = row.id_aluno
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id, np.random.choice(cursos.index, p=prob)]
        todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns=['id_aluno', 'id_curso'])
matriculas
# Out:
#      id_aluno  id_curso
# 0         235        14
# 1          43        20
# 2          43         9
# 3          43        20
# 4          43         6
# ..        ...       ...
# 843       323        14
# 844       383        13
# 845       366        11
# 846       366         9
# 847       366         6
#
# [848 rows x 2 columns]

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['nome_do_curso']).rename(columns={'id_aluno' : 'quantidade_de_alunos'})

# %%
nomes.sample(3)
# Out:
#        nome  id_aluno                 dominio                        email  \
# 53   ELAINE       233     @servicodoemail.com    elaine@servicodoemail.com
# 139   OSMAR        71  @dominiodoemail.com.br  osmar@dominiodoemail.com.br
# 38    DIEGO       294  @dominiodoemail.com.br  diego@dominiodoemail.com.br
#
#      matriculas
# 53            2
# 139           2
# 38            2

# %%
cursos.sample(3)
# Out:
#             nome_do_curso
# id
# 18  Programação funcional
# 12        Hardware básico
# 10    Código limpo com C#

# %%
matriculas.sample(3)
# Out:
#      id_aluno  id_curso
# 26        218         6
# 193       166        13
# 843       323        14

# %%
matriculas_por_curso.sample(3)
# Out:
#           quantidade_de_alunos  nome_do_curso
# id_curso
# 3                           40    C# para Web
# 7                           54  .NET para web
# 6                           88  PHP com MySql

# %% [markdown]
# # Criando o banco SQL:

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect # adicionando o método inspect

engine = create_engine('sqlite:///:memory:')

matriculas_por_curso.to_sql('matriculas', engine)

inspector = inspect(engine) # criando um Inspector object
print(inspector.get_table_names()) # Exibindo as tabelas com o inspecto
# Out:
# ['matriculas']

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
inspector.get_table_names()
# Out:
# ['matriculas']

# %% [markdown]
# # Buscando no banco SQL:

# %%
query = 'select * from matriculas where quantidade_de_alunos < 20'
pd.read_sql(query, engine)
# Out:
#    id_curso  quantidade_de_alunos          nome_do_curso
# 0         2                    10          Java para Web
# 1        12                     5        Hardware básico
# 2        16                     3     Estatística básica
# 3        18                     5  Programação funcional

# %%
pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                    32
# 1                         Java para Web                    10
# 2                           C# para Web                    40
# 3                         Ruby on Rails                    70
# 4                      Cursos de Python                    23
# 5                         PHP com MySql                    88
# 6                         .NET para web                    54
# 7            Novas integrações com Java                    23
# 8                          TDD com Java                    85
# 9                   Código limpo com C#                    63
# 10  Preparatório para certificação Java                    37
# 11                      Hardware básico                     5
# 12                Persistência com .NET                    64
# 13                  Desenvolvendo jogos                    38
# ...

# %%
all_matriculas = pd.read_sql_table('matriculas', engine, columns=['nome_do_curso', 'quantidade_de_alunos'])
all_matriculas
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                    32
# 1                         Java para Web                    10
# 2                           C# para Web                    40
# 3                         Ruby on Rails                    70
# 4                      Cursos de Python                    23
# 5                         PHP com MySql                    88
# 6                         .NET para web                    54
# 7            Novas integrações com Java                    23
# 8                          TDD com Java                    85
# 9                   Código limpo com C#                    63
# 10  Preparatório para certificação Java                    37
# 11                      Hardware básico                     5
# 12                Persistência com .NET                    64
# 13                  Desenvolvendo jogos                    38
# ...

# %%
all_matriculas = all_matriculas.query('quantidade_de_alunos > 80')
all_matriculas
# Out:
#    nome_do_curso  quantidade_de_alunos
# 5  PHP com MySql                    88
# 8   TDD com Java                    85

# %% [markdown]
# # Escrevendo no banco:

# %%
all_matriculas.to_sql('all_matriculas', con=engine)
# Out:
# 2

# %%
print(engine.table_names())
# Out:
# ['all_matriculas', 'matriculas']
# /tmp/ipykernel_9055/1043810782.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %% [markdown]
# # Nomes dos alunos e alunas da próxima turma:

# %%
matriculas_por_curso.head(20)
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           32                Lógica de programação
# 2                           10                        Java para Web
# 3                           40                          C# para Web
# 4                           70                        Ruby on Rails
# 5                           23                     Cursos de Python
# 6                           88                        PHP com MySql
# 7                           54                        .NET para web
# 8                           23           Novas integrações com Java
# 9                           85                         TDD com Java
# 10                          63                  Código limpo com C#
# 11                          37  Preparatório para certificação Java
# 12                           5                      Hardware básico
# 13                          64                Persistência com .NET
# ...

# %%
matriculas
# Out:
#      id_aluno  id_curso
# 0         235        14
# 1          43        20
# 2          43         9
# 3          43        20
# 4          43         6
# ..        ...       ...
# 843       323        14
# 844       383        13
# 845       366        11
# 846       366         9
# 847       366         6
#
# [848 rows x 2 columns]

# %%
id_curso_est = 16
prox_turma = matriculas.query(f'id_curso == {id_curso_est}')
prox_turma
# Out:
#      id_aluno  id_curso
# 71         76        16
# 231       371        16
# 647       194        16

# %%
nomes.sample(5)
# Out:
#            nome  id_aluno                 dominio  \
# 124        LAIS       280  @dominiodoemail.com.br
# 52       SAMUEL       220  @dominiodoemail.com.br
# 128       JOICE       357     @servicodoemail.com
# 95   ALESSANDRO        47     @servicodoemail.com
# 127     JULIANO       374  @dominiodoemail.com.br
#
#                              email  matriculas
# 124     lais@dominiodoemail.com.br           1
# 52    samuel@dominiodoemail.com.br           1
# 128       joice@servicodoemail.com           1
# 95   alessandro@servicodoemail.com           4
# 127  juliano@dominiodoemail.com.br           4

# %%
prox_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso       nome                 dominio  \
# id_aluno
# 76              16  JAQUELINE     @servicodoemail.com
# 371             16     MILENA  @dominiodoemail.com.br
# 194             16       JOEL  @dominiodoemail.com.br
#
#                                  email  matriculas
# id_aluno
# 76        jaqueline@servicodoemail.com           3
# 371       milena@dominiodoemail.com.br           2
# 194         joel@dominiodoemail.com.br           4

# %%
prox_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))[['nome']]
# Out:
#                nome
# id_aluno
# 76        JAQUELINE
# 371          MILENA
# 194            JOEL

# %%
nome_curso = cursos.loc[id_curso_est]
nome_curso
# Out:
# nome_do_curso    Estatística básica
# Name: 16, dtype: object

# %%
nome_curso = nome_curso.nome_do_curso
nome_curso
# Out:
# 'Estatística básica'

# %%
prox_turma = prox_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
prox_turma = prox_turma.rename(columns={'nome' : f'Alunos do curso de {nome_curso}'})
prox_turma
# Out:
#          Alunos do curso de Estatística básica
# id_aluno
# 76                                   JAQUELINE
# 371                                     MILENA
# 194                                       JOEL

# %% [markdown]
# # Exportando para Excel:

# %%
prox_turma.to_excel('prox_turma.xlsx', index=False)
